# %%
import numpy as np
import matplotlib.pyplot as plt

from psygine.decoders.mri.sens.fake_coils import (
    generate_mri_coil_sensitivities,
    show_coils,
)

# %%
SEs = generate_mri_coil_sensitivities(256, 256, 40, 12, smoothing_width=1)

# %%
show_coils(SEs)

# %%
show_coils(SEs)
