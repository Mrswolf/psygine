# %%
import numpy as np
from psygine.decoders.utils import fftmodn, fftnc, profile

# %%
np.random.seed(42)

shape = [256, 256, 256]
X = np.random.randn(*shape) + 1j* np.random.randn(*shape)

# %%
Y1 = profile(fftnc)(X)
# Out:
# Timer unit: 0.001 s
#
# Total time: 0.496699 s
# File: /home/swolf/MyProjects/psygine/psygine/decoders/utils/fourier.py
# Function: fftnc at line 163
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    163                                           def fftnc(X, axes=None, workers=-1):
#    164                                               r"""Nd FFT.
#    165
#    166                                               Parameters
#    167                                               ----------
#    168                                               X : array_like
#    169                                                   Input array, can be complex.
#    170
#    171                                               Returns
#    172                                               -------
#    173                                               K : array_like
#    174                                                   K-space data.
# ...

# %%
Y1 = profile(fftmodn)(X)
# Out:
# Timer unit: 0.001 s
#
# Total time: 0.548276 s
# File: /home/swolf/MyProjects/psygine/psygine/decoders/utils/fourier.py
# Function: fftmodn at line 413
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    413                                           def fftmodn(X, axes=None, workers=-1):
#    414                                               r"""Nd FFT replacing fftshift/ifftshift with phase modulations.
#    415
#    416                                               Parameters
#    417                                               ----------
#    418                                               X : array_like
#    419                                                   Input array, can be complex.
#    420                                               axes : tuple of int, optional
#    421                                                   Axes over which to compute the FFT. If not given, all axes are used.
# ...
